# %% [markdown]
# # Koalas Hands-on Exercise

# %%
import pandas as pd
import pyspark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File <command-4233233435148009>:1
# ----> 1 import findspark
#       2 findspark.init()
#       4 import pandas as pd
#
# File /databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py:171, in _create_import_patch.<locals>.import_patch(name, globals, locals, fromlist, level)
#     166 thread_local._nest_level += 1
#     168 try:
#     169     # Import the desired module. If you’re seeing this while debugging a failed import,
#     170     # look at preceding stack frames for relevant error information.
# --> 171     original_result = python_builtin_import(name, globals, locals, fromlist, level)
#     173     is_root_import = thread_local._nest_level == 1
#     174     # `level` represents the number of leading dots in a relative import statement.
# ...

# %%
import numpy as np
import pandas as pd
import databricks.koalas as ks
# Out:
# WARNING:root:Found pyspark version "3.3.2.dev0" installed. The pyspark version 3.2 and above has a built-in "pandas APIs on Spark" module ported from Koalas. Try `import pyspark.pandas as ps` instead.

# %% [markdown]
# ### Basic functions

# %%
pser = pd.Series([1, 3, 5, np.nan, 6, 8]) 

kser = ks.Series([1, 3, 5, np.nan, 6, 8])


kser = ks.Series(pser)
kser = ks.from_pandas(pser)

# %%
kser.sort_index()
# Out:
# Out[4]: 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# making pandas df from dictionary and converted to koalas df

# %%
pdf = pd.DataFrame({'A': np.random.rand(5),
                    'B': np.random.rand(5)})


kdf = ks.from_pandas(pdf)

# %% [markdown]
# ### Data visualizations

# %%
kdf.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>5.000000</td>
#       <td>5.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.468410</td>
#       <td>0.676506</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.226289</td>
#       <td>0.295569</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.216058</td>
#       <td>0.154922</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>0.281129</td>
#       <td>0.758486</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.453899</td>
# ...

# %%
kdf.sort_values(by='B')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0.216058</td>
#       <td>0.154922</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.453899</td>
#       <td>0.758486</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.658501</td>
#       <td>0.761140</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>0.732466</td>
#       <td>0.838067</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.281129</td>
#       <td>0.869916</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
kdf.transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>0.732466</td>
#       <td>0.281129</td>
#       <td>0.453899</td>
#       <td>0.216058</td>
#       <td>0.658501</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>0.838067</td>
#       <td>0.869916</td>
#       <td>0.758486</td>
#       <td>0.154922</td>
#       <td>0.761140</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Selection

# %%
kdf[['A', 'B']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.732466</td>
#       <td>0.838067</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.281129</td>
#       <td>0.869916</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.453899</td>
#       <td>0.758486</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.216058</td>
#       <td>0.154922</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.658501</td>
#       <td>0.761140</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
kdf.loc[1:2]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0.281129</td>
#       <td>0.869916</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.453899</td>
#       <td>0.758486</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
kdf.iloc[:3, 1:2]
# Out:
# /databricks/spark/python/pyspark/sql/dataframe.py:170: UserWarning: DataFrame.sql_ctx is an internal property, and will be removed in future releases. Use DataFrame.sparkSession instead.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/dataframe.py:149: UserWarning: DataFrame constructor is internal. Do not directly use it.
#   warnings.warn("DataFrame constructor is internal. Do not directly use it.")
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.838067</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.869916</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Applying Python functions to Koalas

# %%
#apply function cumalative sum

# %%
kdf.apply(np.cumsum)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.732466</td>
#       <td>0.838067</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.013595</td>
#       <td>1.707983</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.467494</td>
#       <td>2.466469</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.683552</td>
#       <td>2.621391</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.342052</td>
#       <td>3.382531</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
kdf.apply(lambda x: x ** 2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.536506</td>
#       <td>0.702356</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.079033</td>
#       <td>0.756754</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.206024</td>
#       <td>0.575301</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.046681</td>
#       <td>0.024001</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.433623</td>
#       <td>0.579334</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Grouping data

# %%
kdf.groupby(['A', 'B']).sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0.732466</th>
#       <th>0.838067</th>
#     </tr>
#     <tr>
#       <th>0.281129</th>
#       <th>0.869916</th>
#     </tr>
#     <tr>
#       <th>0.453899</th>
#       <th>0.758486</th>
#     </tr>
#     <tr>
#       <th>0.216058</th>
#       <th>0.154922</th>
#     </tr>
#     <tr>
#       <th>0.658501</th>
#       <th>0.761140</th>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Generating graphics

# %%
# %matplotlib inline

# %%
#create list to ks df and visualixe it

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']
kdf = ks.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)
kdf.plot.barh()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#create date and dictionary and make ks df

# %%
# Define the date range with the correct length
date_range = pd.date_range(start='2019/08/15', end='2020/03/09', freq='D')

# Generate sample data with the correct length
data = {
    'sales': np.random.randint(1, 10, len(date_range)),
    'signups': np.random.randint(5, 15, len(date_range)),
    'visits': np.random.randint(20, 100, len(date_range)),
}

# Create the Koalas DataFrame
kdf = ks.DataFrame(data, index=date_range)
kdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sales</th>
#       <th>signups</th>
#       <th>visits</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2019-08-15</th>
#       <td>8</td>
#       <td>10</td>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>2019-08-16</th>
#       <td>7</td>
#       <td>9</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>2019-08-17</th>
#       <td>9</td>
#       <td>5</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>2019-08-18</th>
#       <td>7</td>
#       <td>10</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>2019-08-19</th>
#       <td>6</td>
#       <td>7</td>
# ...

# %%
# Create the Koalas DataFrame
kdf = ks.DataFrame(data, index=date_range)
kdf.plot.area()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Using SQL in Koalas

# %%
kdf = ks.DataFrame({'year': [1990, 1997, 2003, 2009, 2014],
                    'pig': [20, 18, 489, 675, 1776],
                    'horse': [4, 25, 281, 600, 1900]})

# %%
ks.sql("SELECT * FROM {kdf} WHERE pig > 100")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>pig</th>
#       <th>horse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2003</td>
#       <td>489</td>
#       <td>281</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2009</td>
#       <td>675</td>
#       <td>600</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2014</td>
#       <td>1776</td>
#       <td>1900</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pdf = pd.DataFrame({'year': [1990, 1997, 2003, 2009, 2014],
                    'sheep': [22, 50, 121, 445, 791],
                    'chicken': [250, 326, 589, 1241, 2118]})

# %%
ks.sql('''
    SELECT ks.pig, pd.chicken
    FROM {kdf} ks INNER JOIN {pdf} pd
    ON ks.year = pd.year
    ORDER BY ks.pig, pd.chicken''')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pig</th>
#       <th>chicken</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18</td>
#       <td>326</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20</td>
#       <td>250</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>489</td>
#       <td>589</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>675</td>
#       <td>1241</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1776</td>
#       <td>2118</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Working with PySpark

# %%
kdf = ks.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]})
sdf = kdf.to_spark()
type(sdf)
# Out:
# Out[35]: pyspark.sql.dataframe.DataFrame

# %%
sdf.show()
# Out:
# +---+---+
# |  A|  B|
# +---+---+
# |  1| 10|
# |  2| 20|
# |  3| 30|
# |  4| 40|
# |  5| 50|
# +---+---+
